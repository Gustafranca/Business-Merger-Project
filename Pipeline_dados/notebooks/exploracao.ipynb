# %%
import pandas as pd


data_A = pd.read_json("../data_raw/dados_empresaA.json")
data_B = pd.read_csv("../data_raw/dados_empresaB.csv")

# %%
data_A.head(5)
# Out:
#         Nome do Produto Categoria do Produto  Preço do Produto (R$)  \
# 0           Blush em pó     Eletrodomésticos                  79.41
# 1  Lápis de sobrancelha     Eletrodomésticos                  85.47
# 2          Base líquida               Roupas                  75.02
# 3          Base líquida               Roupas                  44.94
# 4  Lápis de sobrancelha            Alimentos                  58.63
#
#    Quantidade em Estoque     Filial
# 0                      7   Filial 7
# 1                     78   Filial 8
# 2                     34   Filial 8
# 3                     90  Filial 10
# 4                     91   Filial 7

# %%
data_B.head()
# Out:
#            Nome do Item Classificação do Produto  Valor em Reais (R$)  \
# 0  Lápis de sobrancelha                   Roupas                55.17
# 1           Batom matte              Eletrônicos                74.15
# 2             Corretivo                   Roupas                54.86
# 3    Delineador líquido                   Roupas                91.29
# 4         Batom líquido                   Roupas                44.65
#
#    Quantidade em Estoque Nome da Loja               Data da Venda
# 0                     62     Filial 1  2023-04-13 18:58:06.794203
# 1                     48     Filial 9  2023-06-03 18:58:06.794203
# 2                     36     Filial 5  2023-06-08 18:58:06.794203
# 3                      1     Filial 8  2023-02-27 18:58:06.794203
# 4                     52     Filial 2  2022-09-05 18:58:06.794203

# %%
#padronizar 'Nome do produto' e 'Nome do Item'
#padronizar 'Preço do Produto (R$) e 'Valor em Reais (R$)
#dropar coluna 'Data da venda' 
#padronizar 'Nome da loja' e 'Filial'

# %%
data_processed = pd.read_csv("../data_processed/dados_combinados.csv")
data_processed_ordedby_filial = data_processed.sort_values(by='Filial')
data_processed_ordedby_filial.head()
# Out:
#         Nome do Produto Categoria do Produto  Preço do Produto (R$)  \
# 1609        Batom matte               Roupas                  95.08
# 4154  Máscara de cílios          Eletrônicos                  41.16
# 728   Máscara de cílios               Roupas                  40.61
# 735     Sombra de olhos          Eletrônicos                  26.45
# 743         Pó compacto            Alimentos                  98.51
#
#       Quantidade em Estoque    Filial               Data da Venda
# 1609                     24  Filial 1                Indisponivel
# 4154                     57  Filial 1  2023-05-20 18:58:06.794203
# 728                       3  Filial 1                Indisponivel
# 735                      98  Filial 1                Indisponivel
# 743                      39  Filial 1                Indisponivel
